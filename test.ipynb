# %%
import pandas as pd

df = pd.read_parquet("data/processed/TOTF.PA-book/2017-01-02-TOTF.PA-book.parquet")

# %%
df.head()
# Out:
#          xltime  bid-price-1  bid-volume-1  ask-price-1  ask-volume-1  \
# 0  42737.378027       48.760          1599        48.78           960
# 1  42737.378027       48.760           620        48.78           960
# 2  42737.378027       48.755          1695        48.78           960
# 3  42737.378027       48.765           458        48.78           960
# 4  42737.378027       48.765           258        48.78           960
#
#    bid-price-2  bid-volume-2  ask-price-2  ask-volume-2  bid-price-3  ...  \
# 0       48.755          1695       48.785          1775       48.750  ...
# 1       48.755          1695       48.785          1775       48.750  ...
# 2       48.750          1488       48.785          1775       48.745  ...
# 3       48.760          1599       48.785          1775       48.755  ...
# 4       48.760          1599       48.785          1775       48.755  ...
#
#    Hawkes_M_ask_beta10  Hawkes_M_bid_beta100  Hawkes_M_ask_beta100  \
# ...
